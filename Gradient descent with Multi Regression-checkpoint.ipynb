# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os 
os.chdir(r"C:\Users\...\Gradient descent with Multi Regression")

# %%
startups = pd.read_csv("50_Startups.csv")
df = startups.copy()
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
#correlation
corr = df.corr()
corr
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
#correlation using seaborn 
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x = "R&D Spend", y = "Profit", data = df , color = "r" )
# Out:
# <AxesSubplot:xlabel='R&D Spend', ylabel='Profit'>

# %%
df.hist(figsize = (13,10))
plt.show()

# %%
#Transpose columns t rows Describe
df.describe().T
# Out:
#                  count         mean            std       min          25%  \
# R&D Spend         50.0   73721.6156   45902.256482      0.00   39936.3700
# Administration    50.0  121344.6396   28017.802755  51283.14  103730.8750
# Marketing Spend   50.0  211025.0978  122290.310726      0.00  129300.1325
# Profit            50.0  112012.6392   40306.180338  14681.40   90138.9025
#
#                         50%          75%        max
# R&D Spend         73051.080  101602.8000  165349.20
# Administration   122699.795  144842.1800  182645.56
# Marketing Spend  212716.240  299469.0850  471784.10
# Profit           107978.190  139765.9775  192261.83

# %%
df["State"].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df_state = pd.get_dummies(df["State"])
df_state
# Out:
#     California  Florida  New York
# 0            0        0         1
# 1            1        0         0
# 2            0        1         0
# 3            0        0         1
# 4            0        1         0
# 5            0        0         1
# 6            1        0         0
# 7            0        1         0
# 8            0        0         1
# 9            1        0         0
# 10           0        1         0
# 11           1        0         0
# 12           0        1         0
# 13           1        0         0
# 14           0        1         0
# 15           0        0         1
# 16           1        0         0
# 17           0        0         1
# 18           0        1         0
# 19           0        0         1
# 20           1        0         0
# 21           0        0         1
# 22           0        1         0
# 23           0        1         0
# 24           0        0         1
# 25           1        0         0
# ...

# %%
# to add "state" before 
df_dummies = pd.get_dummies(df["State"],prefix = "state")

# %%
df_dummies
# Out:
#     state_California  state_Florida  state_New York
# 0                  0              0               1
# 1                  1              0               0
# 2                  0              1               0
# 3                  0              0               1
# 4                  0              1               0
# 5                  0              0               1
# 6                  1              0               0
# 7                  0              1               0
# 8                  0              0               1
# 9                  1              0               0
# 10                 0              1               0
# 11                 1              0               0
# 12                 0              1               0
# 13                 1              0               0
# 14                 0              1               0
# 15                 0              0               1
# 16                 1              0               0
# ...

# %%
# to add dummy data  in one column to my data
df = pd.concat([df,df_dummies], axis = 1 )

# %%
df = df.drop(["state_Florida"], axis = 1 )

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    state_California  state_New York
# 0                 0               1
# 1                 1               0
# 2                 0               0
# 3                 0               1
# 4                 0               0

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df = df.drop(["State"] , axis = 1)

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  state_California  \
# 0  165349.20       136897.80        471784.10  192261.83                 0
# 1  162597.70       151377.59        443898.53  191792.06                 1
# 2  153441.51       101145.55        407934.54  191050.39                 0
# 3  144372.41       118671.85        383199.62  182901.99                 0
# 4  142107.34        91391.77        366168.42  166187.94                 0
#
#    state_New York
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0

# %%
#Spliting Date 
X = df.drop("Profit", axis = 1)
y = df["Profit"]

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend  state_California  \
# 0   165349.20       136897.80        471784.10                 0
# 1   162597.70       151377.59        443898.53                 1
# 2   153441.51       101145.55        407934.54                 0
# 3   144372.41       118671.85        383199.62                 0
# 4   142107.34        91391.77        366168.42                 0
# 5   131876.90        99814.71        362861.36                 0
# 6   134615.46       147198.87        127716.82                 1
# 7   130298.13       145530.06        323876.68                 0
# 8   120542.52       148718.95        311613.29                 0
# 9   123334.88       108679.17        304981.62                 1
# 10  101913.08       110594.11        229160.95                 0
# 11  100671.96        91790.61        249744.55                 1
# 12   93863.75       127320.38        249839.44                 0
# ...

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 35 , random_state = 35)

# %%
from sklearn.linear_model import LinearRegression

# %%
ln = LinearRegression()

# %%
model = ln.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 85843.09388707, 114098.3803761 , 115395.33133379,  98689.51230684,
#        102366.05270165,  63494.85653777,  80638.72402225, 127304.94747655,
#        102134.99959539, 111598.86650932,  92567.42330148, 173843.09445822,
#        130587.48560936, 101706.19900824, 149801.40752336,  57698.8829266 ,
#         85933.60226656, 182378.66961232, 114315.77318013,  93140.37058558,
#        138972.49057456, 181955.22254499,  77735.12903804, 114973.59065211,
#        158481.55065146, 103162.99876076, 161814.01071873, 159411.19468813,
#        116433.80966407,  73123.72250485, 125136.94749327,  51053.73626403,
#         56712.60788524, 118952.05751097, 170442.96120508])

# %%
df = pd.DataFrame({"y_test" : y_test , "y_pred" : y_pred 
                       , "diff between y_pred & y_test" : abs(y_pred-y_test)})

df
# Out:
#        y_test         y_pred  diff between y_pred & y_test
# 39   81005.76   85843.093887                   4837.333887
# 26  105733.54  114098.380376                   8364.840376
# 22  110352.25  115395.331334                   5043.081334
# 31   97483.56   98689.512307                   1205.952307
# 29  101004.64  102366.052702                   1361.412702
# 43   69758.98   63494.856538                   6264.123462
# 41   77798.83   80638.724022                   2839.894022
# 17  125370.37  127304.947477                   1934.577477
# 25  107404.34  102134.999595                   5269.340405
# 23  108733.99  111598.866509                   2864.876509
# 35   96479.51   92567.423301                   3912.086699
# 4   166187.94  173843.094458                   7655.154458
# 18  124266.90  130587.485609                   6320.585609
# 32   97427.84  101706.199008                   4278.359008
# 14  132602.65  149801.407523                  17198.757523
# ...

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, y_pred)
MAE
# Out:
# 7604.296966237859

# %%
#calculate root mean square error
RMSE = np.sqrt(MAE)
RMSE
# Out:
# 87.20262017988829

# %%
model.score(X_train, y_train)
# Out:
# 0.9665802235402201

# %%
df1 = startups.head()
df1.plot(kind = "bar", figsize= (16,10))
plt.grid(which='major', linestyle = '-', linewidth = "0.5", c = "g")
plt.show()

# %%
# Intercept and coefficient  the line
print(" The Intercept of the model (b value) : \n " , ln.intercept_)
print("%"*50)
print("The coefficient of the model (m value) : \n ", ln.coef_)
# Out:
#  The Intercept of the model (b value) :
#   64667.39205147546
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# The coefficient of the model (m value) :
#   [ 8.15409941e-01 -8.61966413e-02  3.21608374e-03 -3.67532548e+03
#  -2.95041634e+03]

# %%
# Using  backward elimination to make a feature selection to get the best column
import statsmodels.api as sm
#Ordinary Least Squares == OLS
stmodel = sm.OLS(y,X).fit()

# %%
stmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              765.9
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):                    2.49e-42
# Time:                        15:32:26   Log-Likelihood:                         -543.87
# No. Observations:                  50   AIC:                                      1098.
# Df Residuals:                      45   BIC:                                      1107.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
# adding constant column
X = sm.add_constant(X)
stmodel = sm.OLS(y,X).fit()
stmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):           1.34e-27
# Time:                        15:36:12   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
X = X.drop(["state_California"], axis = 1)
model = sm.OLS(y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):           8.50e-29
# Time:                        15:40:43   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X = X.drop(["state_New York"], axis = 1)
model = sm.OLS(y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):           4.53e-30
# Time:                        15:42:07   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X = X.drop(["Administration"], axis = 1)
model = sm.OLS(y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):           2.16e-31
# Time:                        15:42:27   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X = X.drop(["Marketing Spend"], axis = 1)
model = sm.OLS(y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):           3.50e-32
# Time:                        15:43:49   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...
